# %% [markdown]
# <a href="https://colab.research.google.com/github/Briiieeee-M8/fa3programactivity/blob/main/fa3progr1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#student info asker whatev

name = input("enter name")
age = input("enter age")
course = input("enter course")
print("Name:", name)
print("Age:", age)
print("Course", course)
# Out:
# enter nameBree
# enter age18
# enter courseat
# Name: Bree
# Age: 18
# Course at
