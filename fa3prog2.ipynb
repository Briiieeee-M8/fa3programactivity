# %% [markdown]
# <a href="https://colab.research.google.com/github/Briiieeee-M8/fa3programactivity/blob/main/fa3prog2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pass/fail checker

exam_score = int(input("enter score"))
if exam_score >= 74:
 print("Passed")
else:
  if exam_score <= 75:
    print("Failed")
# Out:
# enter score73
# Failed
