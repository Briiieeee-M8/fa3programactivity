# %% [markdown]
# <a href="https://colab.research.google.com/github/Briiieeee-M8/fa3programactivity/blob/main/fa3prog3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import GRND_NONBLOCK
name = input("enter name")
print("name:", name)
score = int(input("enter score"))
if score >= 90 and score <= 100:
  print("grade = A")
elif score >= 80 and score <= 89:
  print("grade = B")
elif score >= 70 and score <= 79:
  print("grade = C")
else:
  print("grade = F")
# Out:
# enter nameBree
# name: Bree
# enter score64
# grade = F
